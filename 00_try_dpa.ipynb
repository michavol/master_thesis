# %%
import torch
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
torch.cuda.is_available()
# Out:
# False

# %%
import torch
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets
import sys
sys.path.append("..")
from dpa.dpa_fit import DPA

# %%
# Read adata
import scanpy as sc
import anndata
import pandas as pd

adata = sc.read_h5ad("data/proteomics/data/preprocessed_small.h5ad") #730 × 5519

# only consider first 100 proteins
adata = adata[:,0:100]

# %%
dpa = DPA(data_dim=100, latent_dims=[10,8,5,2], num_layer=6, hidden_dim=50, device=device)
# Out:
# Running on CPU.

# %%
x_tr = torch.tensor(adata.X[:500], dtype=torch.float32).to(device)
x_te = torch.tensor(adata.X[500:700], dtype=torch.float32).to(device)

# %%
dpa.train(x_tr, x_tr, batch_size=32, num_epochs=1000, print_every_nepoch=1)
# Out:
# Start training with 16 batches each of size 32.
# /home/mike/Masters_DS/master_thesis/.venv/lib/python3.10/site-packages/torch/amp/autocast_mode.py:266: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# [Epoch 1] 7.6130, 7.5958, 7.5818, 7.6021
#  pred 	11.3545, 11.4340, 11.4433, 11.5576
#  var 	7.4830, 7.6764, 7.7231, 7.9109
# (test)	7.5370, 7.5530, 7.5523, 7.5536
#  pred 	11.3412, 11.3576, 11.4222, 11.4946
#  var 	7.6084, 7.6093, 7.7398, 7.8821
#
# [Epoch 2] 7.5177, 7.4850, 7.4837, 7.4926
#  pred 	11.2739, 11.2969, 11.3315, 11.4519
#  var 	7.5123, 7.6238, 7.6956, 7.9185
# (test)	7.4585, 7.4580, 7.4781, 7.4685
#  pred 	11.2508, 11.2957, 11.3951, 11.4200
#  var 	7.5846, 7.6754, 7.8339, 7.9029
#
# [Epoch 3] 7.4113, 7.4165, 7.4231, 7.4396
#  pred 	11.2027, 11.2557, 11.3190, 11.3892
#  var 	7.5828, 7.6783, 7.7918, 7.8993
# (test)	7.4337, 7.4175, 7.4565, 7.4434
#  pred 	11.2362, 11.2742, 11.3717, 11.3849
# ...
