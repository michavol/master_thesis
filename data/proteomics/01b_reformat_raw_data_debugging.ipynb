# %%
import pandas as pd

# %%
# ----------------------------------------------------------------------
# 1. Read data
# ----------------------------------------------------------------------
# Adjust the path/filename as needed:
dat = pd.read_csv('data/ProteinMatrix_sampleID_MapEC50_20240229.csv', index_col="Sample_ID")
# Out:
# /tmp/ipykernel_5829/561404019.py:5: DtypeWarning: Columns (0,5587,5588,5589,5590,5591,5592,5593,5596,5599,5600,5601,5603,5604,5606,5614) have mixed types. Specify dtype option on import or set low_memory=False.
#   dat = pd.read_csv('data/ProteinMatrix_sampleID_MapEC50_20240229.csv', index_col="Sample_ID")

# %%
# ----------------------------------------------------------------------
# 2. Get protein Data
# ----------------------------------------------------------------------
p_idx_end = 5585
data_protein = dat.iloc[:, :p_idx_end].copy()

# %%
# ----------------------------------------------------------------------
# 3. Remove columns with only one unique value
# ----------------------------------------------------------------------
unique_counts = data_protein.nunique(dropna=False)
cols_to_remove = unique_counts[unique_counts == 1].index
data_protein.drop(columns=cols_to_remove, inplace=True)

# Keep only columns with "HUMAN" in their name (as in R code)
data_protein = data_protein.loc[:, data_protein.columns.str.contains("HUMAN")]

# %%
def na_imputation(series: pd.Series) -> pd.Series:
    """
    Replace NA values with 0.8 * min of the series (excluding NA).
    Equivalent to the na_imputation() function in R.
    """
    min_val = series.min(skipna=True)
    series_filled = series.fillna(min_val * 0.8)
    return series_filled

# %%
# ----------------------------------------------------------------------
# 4. Impute missing values
# ----------------------------------------------------------------------
data_protein = data_protein.apply(na_imputation)

# %%
# ----------------------------------------------------------------------
# 5. Log transform
# ----------------------------------------------------------------------
import numpy as np
data_protein = np.log(data_protein)

# %%
# ----------------------------------------------------------------------
# 6. Merge information of both sub xlsx of individual and combination drug information
# ----------------------------------------------------------------------
# This is necessary because the columns are split across two files in the original data. See description in bottom https://db.prottalks.com/views/PTV1.html
drugs = dat['pert_id'].astype(str)
# Convert to one-hot (pandas.get_dummies is similar to fastDummies in R)
data_drugs = pd.get_dummies(drugs, prefix='drug', dtype=float)

# %%
# Remove information on controls and combinations (which we deal with later)
for col in ['drug_no', 'drug_nan']:
    if col in data_drugs.columns:
        data_drugs.drop(columns=col, inplace=True)

# Multiply the entire drug matrix by 10 to indicate the dosage for single treatment experiments 10uM
data_drugs *= 10

# %%
# ----------------------------------------------------------------------
# 7. Identify combination rows (where drug_ was blank in R)
# ----------------------------------------------------------------------
combination_idx = dat.index[dat['pert_id'].isna()].tolist()  # all entries with nans correspond to drug combinations

# %%
# ----------------------------------------------------------------------
# 8. Adjust the one-hot encoding for combination and directly include doses
# ----------------------------------------------------------------------
for i in combination_idx:
    # 'drugIdAB' holds something like 'A B' for the two drugs
    drugAB = str(dat.loc[i, 'drugIdAB']).split()
    # Prepend 'drug_' to match the column naming
    drugAB_cols = [f"drug_{d}" for d in drugAB]
    
    anchor_dose = dat.loc[i, 'Anchor_dose']
    library_dose = dat.loc[i, 'Library_dose']
    
    # If the columns exist, set them accordingly - this skips the "drug_no" examples, so the controls for the combination exp
    if drugAB_cols[0] in data_drugs.columns:
        data_drugs.at[i, drugAB_cols[0]] = anchor_dose
    if drugAB_cols[1] in data_drugs.columns:
        data_drugs.at[i, drugAB_cols[1]] = library_dose

    # This way each row for drug combinations will have two non-zero values.

# %%
# ----------------------------------------------------------------------
# 9. Additional metadata columns
# ----------------------------------------------------------------------
data_additional = dat[['pert_time', 'protein_plate', 'machine', 'BioRep',
                        'Anchor_dose', 'Library_dose']].copy()
data_additional['Anchor_dose'] = data_additional['Anchor_dose'].fillna(0)
data_additional['Library_dose'] = data_additional['Library_dose'].fillna(0)

# %%
# ----------------------------------------------------------------------
# 10. Response data: singleDrug uses 'EC50', combos use 'Combo.IC50'
# ----------------------------------------------------------------------
data_response = dat['EC50'].copy()
combo_ic50 = dat['Combo.IC50'].copy()
data_response.loc[combination_idx] = combo_ic50.loc[combination_idx]

# %%
# ----------------------------------------------------------------------
# 11. Type and pertLabel columns
# ----------------------------------------------------------------------
# Mark as 'drugCombination' for combos, 'singleDrug' otherwise, 'noDrug' if 'no'
type_col = pd.Series(['singleDrug'] * len(dat), index=dat.index)
type_col.loc[combination_idx] = 'drugCombination'

combination_control_mask = dat["drugIdAB"] == 'no no'
type_col.loc[(drugs == 'no') | combination_control_mask] = 'noDrug'

# %%
pertLabel = dat['pert_id'].astype(str).copy()
# For combos, set label to drugIdAB
pertLabel.loc[combination_idx] = dat.loc[combination_idx, 'drugIdAB'].astype(str)

# %%
# If 'no no' or 'no' means no drug, we can handle that similarly:
# data_response[pertLabel == 'no'] = np.inf  # e.g. replicate R's assignment of Inf

# ----------------------------------------------------------------------
# 12. Combine everything
# ----------------------------------------------------------------------
data_final = pd.concat([data_protein,
                        data_drugs,
                        data_additional], axis=1)
data_final['type'] = type_col.values
data_final['pertLabel'] = pertLabel.values
data_final['IC50'] = data_response.values
data_final['NY'] = dat['NY'].values  # If that column exists

# %%
# ----------------------------------------------------------------------
# 13. Log2 transform of singleDrug IC50 only
# ----------------------------------------------------------------------
single_drug_mask = (data_final['type'] == 'singleDrug') & data_final['IC50'].notna()
data_final.loc[single_drug_mask, 'IC50'] = np.log2(data_final.loc[single_drug_mask, 'IC50'])

# %%
data_final.head()
# Out:
#            Q8WUW1.Q8WUW1.BRK1_HUMAN.BRK1.Protein.BRICK1  \
# Sample_ID
# B1422                                          2.237325
# B5718                                          2.237325
# B3832                                          2.237325
# B3637                                          2.237325
# B532                                           2.237325
#
#            Q9NRR4.Q9NRR4.RNC_HUMAN.DROSHA.Ribonuclease.3  \
# Sample_ID
# B1422                                           4.951632
# B5718                                           4.951632
# B3832                                           4.951632
# B3637                                           4.951632
# B532                                            4.951632
#
#            Q99747.Q99747.SNAG_HUMAN.NAPG.Gamma.soluble.NSF.attachment.protein  \
# Sample_ID
# B1422                                               4.006710
# B5718                                               7.605178
# B3832                                               6.776822
# B3637                                               5.743561
# B532                                                4.006710
#
#            P10398.P10398.ARAF_HUMAN.ARAF.Serine.threonine.protein.kinase.A.Raf  \
# Sample_ID
# B1422                                               4.239126
# B5718                                               4.239126
# B3832                                               4.239126
# B3637                                               4.239126
# B532                                                4.239126
#
#            P05198.P05198.IF2A_HUMAN.EIF2S1.Eukaryotic.translation.initiation.factor.2.subunit.1  \
# Sample_ID
# B1422                                               8.437013
# B5718                                               8.655340
# B3832                                               8.686840
# B3637                                               8.561968
# B532                                                8.487018
#
#            Q6P1N0.Q6P1N0.C2D1A_HUMAN.CC2D1A.Coiled.coil.and.C2.domain.containing.protein.1A  \
# Sample_ID
# B1422                                               3.734398
# B5718                                               3.734398
# B3832                                               3.734398
# B3637                                               3.734398
# B532                                                3.734398
#
#            Q14807.Q14807.KIF22_HUMAN.KIF22.Kinesin.like.protein.KIF22  \
# Sample_ID
# B1422                                               6.267629
# B5718                                               2.965665
# B3832                                               2.965665
# B3637                                               2.965665
# B532                                                2.965665
#
#            Q9H269.Q9H269.VPS16_HUMAN.VPS16.Vacuolar.protein.sorting.associated.protein.16.homolog  \
# Sample_ID
# B1422                                                3.58186
# B5718                                                3.58186
# B3832                                                3.58186
# B3637                                                3.58186
# B532                                                 3.58186
#
#            O00461.O00461.GOLI4_HUMAN.GOLIM4.Golgi.integral.membrane.protein.4  \
# Sample_ID
# B1422                                               3.004411
# B5718                                               3.004411
# B3832                                               3.004411
# B3637                                               3.004411
# B532                                                3.004411
#
#            P49257.P49257.LMAN1_HUMAN.LMAN1.Protein.ERGIC.53  ...  pert_time  \
# Sample_ID                                                    ...
# B1422                                              8.912763  ...         48
# B5718                                              9.082839  ...         24
# B3832                                              8.705278  ...         48
# B3637                                              9.072568  ...         48
# B532                                               9.349450  ...         24
#
#            protein_plate  machine  BioRep  Anchor_dose  Library_dose  \
# Sample_ID
# B1422             DU4475        D     1.0          0.0           0.0
# B5718            HCC1187      WAF     3.0          0.0           0.0
# B3832             DU4475        D     2.0          0.0           0.0
# B3637             DU4475        D     3.0          0.0           0.0
# B532              DU4475      WAE     1.0          0.0           0.0
#
#                  type  pertLabel      IC50  NY
# Sample_ID
# B1422      singleDrug        #58  3.453649   Y
# B5718      singleDrug        #25  6.409590   N
# B3832      singleDrug        #58  3.453649   Y
# B3637      singleDrug        #58  3.453649   Y
# B532       singleDrug        #58  3.453649   Y
#
# [5 rows x 5592 columns]

# %%
data_final[data_final["type"] == "drugCombination"]["pertLabel"].value_counts()
# Out:
# pertLabel
# #64 #56    200
# #53 #64    172
# #20 #64    161
# #56 #53    156
# #53 #32    151
# #32 #47    149
# #64 #58    141
# #20 #32    135
# #64 #32    134
# #56 #58    107
# #20 #53    106
# #33 #21    101
# #47 #64    100
# #32 #58     91
# #69 #20     89
# #47 #56     87
# #33 #56     82
# #33 #37     81
# #69 #64     80
# #56 #32     79
# #56 #21     78
# #69 #21     78
# #53 #21     77
# #33 #32     75
# #33 #64     74
# #69 #53     73
# #47 #21     73
# #47 #37     72
# #47 #53     72
# #47 #20     70
# #47 #8      69
# #33 #20     64
# #53 #37     63
# #69 #37     61
# #56 #37     61
# #69 #58     61
# #64 #8      59
# #32 #8      56
# #20 #56     56
# #20 #8      55
# #20 #21     54
# #69 #47     54
# #53 #8      53
# #64 #21     52
# #33 #47     52
# #69 #8      51
# #32 #37     47
# #33 #53     46
# #47 #58     45
# #69 #56     42
# #33 #8      42
# #20 #37     41
# #33 #58     38
# #64 #37     38
# #69 #32     38
# #32 #21     36
# #53 #58     34
# #56 #8      34
# #20 #58     24
# Name: count, dtype: int64

# %%
data_final[data_final["type"] == "drugCombination"].loc[:, ["type", "pertLabel", "protein_plate", "machine", "BioRep", "Anchor_dose", "Library_dose", "pert_time"]].iloc[1000:2000,:]
# Out:
#                       type pertLabel protein_plate machine  BioRep  \
# Sample_ID
# D2913      drugCombination   #32 #47       HCC1806       D     6.0
# D3096      drugCombination   #33 #32       HCC1806       D     1.0
# D2955      drugCombination   #33 #32       HCC1806       D     2.0
# D2957      drugCombination   #33 #32       HCC1806       D     3.0
# D2816      drugCombination   #33 #32       HCC1806       D     4.0
# ...                    ...       ...           ...     ...     ...
# D4474      drugCombination    #33 #8       HCC1395     WAF     1.0
# D4475      drugCombination    #33 #8       HCC1395     WAF     2.0
# D4673      drugCombination    #33 #8       HCC1395       D     3.0
# D4553      drugCombination    #33 #8       HCC1395       D     1.0
# D4552      drugCombination    #33 #8       HCC1395       D     2.0
#
#            Anchor_dose  Library_dose  pert_time
# Sample_ID
# D2913              7.5          10.0          6
# D3096              2.0          10.0         48
# D2955              2.0          10.0         48
# D2957              0.5          10.0         48
# D2816              0.5          10.0         48
# ...                ...           ...        ...
# D4474              0.5          10.0         24
# D4475              2.0          10.0         24
# D4673              2.0          10.0         24
# D4553              2.0          10.0          6
# D4552              0.5          10.0          6
#
# [1000 rows x 8 columns]

# %%
data_final[data_final["pertLabel"] == "#64 #56"][["Anchor_dose","Library_dose"]].value_counts()
# Out:
# Anchor_dose  Library_dose
# 0.10         4.0             61
# 4.00         10.0            53
# 0.01         4.0             43
# 1.00         10.0            43
# Name: count, dtype: int64

# %%
data_final[data_final["type"] == "noDrug"]
# Out:
#            Q8WUW1.Q8WUW1.BRK1_HUMAN.BRK1.Protein.BRICK1  \
# Sample_ID
# B3658                                          2.237325
# B1448                                          2.237325
# B3663                                          2.237325
# B3848                                          2.237325
# B1450                                          5.775294
# ...                                                 ...
# 1618                                           6.649176
# 2478                                           6.945590
# 5550                                           8.260682
# 2457                                           6.574733
# 106                                            7.641780
#
#            Q9NRR4.Q9NRR4.RNC_HUMAN.DROSHA.Ribonuclease.3  \
# Sample_ID
# B3658                                           4.951632
# B1448                                           4.951632
# B3663                                           4.951632
# B3848                                           4.951632
# B1450                                           4.951632
# ...                                                  ...
# 1618                                            4.951632
# 2478                                            4.951632
# 5550                                            9.808451
# 2457                                            9.209205
# 106                                             9.937556
#
#            Q99747.Q99747.SNAG_HUMAN.NAPG.Gamma.soluble.NSF.attachment.protein  \
# Sample_ID
# B3658                                               4.006710
# B1448                                               4.006710
# B3663                                               4.006710
# B3848                                               6.817116
# B1450                                               7.222617
# ...                                                      ...
# 1618                                                8.165378
# 2478                                                8.193328
# 5550                                                7.964323
# 2457                                                8.195265
# 106                                                 8.000346
#
#            P10398.P10398.ARAF_HUMAN.ARAF.Serine.threonine.protein.kinase.A.Raf  \
# Sample_ID
# B3658                                               4.239126
# B1448                                               4.239126
# B3663                                               4.239126
# B3848                                               4.239126
# B1450                                               4.239126
# ...                                                      ...
# 1618                                                6.984698
# 2478                                                6.970505
# 5550                                                4.239126
# 2457                                                6.730493
# 106                                                 4.239126
#
#            P05198.P05198.IF2A_HUMAN.EIF2S1.Eukaryotic.translation.initiation.factor.2.subunit.1  \
# Sample_ID
# B3658                                               8.653434
# B1448                                               8.453550
# B3663                                               8.542982
# B3848                                               8.832653
# B1450                                               9.390359
# ...                                                      ...
# 1618                                                9.537657
# 2478                                                9.623952
# 5550                                                9.640687
# 2457                                                9.656634
# 106                                                 9.391436
#
#            Q6P1N0.Q6P1N0.C2D1A_HUMAN.CC2D1A.Coiled.coil.and.C2.domain.containing.protein.1A  \
# Sample_ID
# B3658                                               3.734398
# B1448                                               3.734398
# B3663                                               3.734398
# B3848                                               3.734398
# B1450                                               7.252529
# ...                                                      ...
# 1618                                                7.887460
# 2478                                                6.878545
# 5550                                                7.306545
# 2457                                                6.592499
# 106                                                 3.734398
#
#            Q14807.Q14807.KIF22_HUMAN.KIF22.Kinesin.like.protein.KIF22  \
# Sample_ID
# B3658                                               2.965665
# B1448                                               2.965665
# B3663                                               2.965665
# B3848                                               2.965665
# B1450                                               2.965665
# ...                                                      ...
# 1618                                                2.965665
# 2478                                                7.349964
# 5550                                                2.965665
# 2457                                                6.172942
# 106                                                 5.972868
#
#            Q9H269.Q9H269.VPS16_HUMAN.VPS16.Vacuolar.protein.sorting.associated.protein.16.homolog  \
# Sample_ID
# B3658                                               3.581860
# B1448                                               3.581860
# B3663                                               3.581860
# B3848                                               3.581860
# B1450                                               6.480123
# ...                                                      ...
# 1618                                                3.581860
# 2478                                                6.310449
# 5550                                                3.581860
# 2457                                                5.754729
# 106                                                 3.581860
#
#            O00461.O00461.GOLI4_HUMAN.GOLIM4.Golgi.integral.membrane.protein.4  \
# Sample_ID
# B3658                                               3.004411
# B1448                                               3.004411
# B3663                                               6.656399
# B3848                                               3.004411
# B1450                                               3.004411
# ...                                                      ...
# 1618                                                3.004411
# 2478                                                3.004411
# 5550                                                3.004411
# 2457                                                3.004411
# 106                                                 3.004411
#
#            P49257.P49257.LMAN1_HUMAN.LMAN1.Protein.ERGIC.53  ...  pert_time  \
# Sample_ID                                                    ...
# B3658                                              8.566749  ...          0
# B1448                                              9.294939  ...          0
# B3663                                              8.891363  ...          0
# B3848                                              8.587171  ...          0
# B1450                                              8.755834  ...          0
# ...                                                     ...  ...        ...
# 1618                                              10.376580  ...          0
# 2478                                              10.159683  ...          0
# 5550                                              10.042253  ...          0
# 2457                                              10.076970  ...          0
# 106                                                9.786043  ...          0
#
#            protein_plate  machine  BioRep  Anchor_dose  Library_dose    type  \
# Sample_ID
# B3658             DU4475        D     1.0          0.0           0.0  noDrug
# B1448             DU4475        D     2.0          0.0           0.0  noDrug
# B3663             DU4475        D     3.0          0.0           0.0  noDrug
# B3848             DU4475        D     4.0          0.0           0.0  noDrug
# B1450             DU4475      WAF     5.0          0.0           0.0  noDrug
# ...                  ...      ...     ...          ...           ...     ...
# 1618               HCC38      WAE     1.0          0.0           0.0  noDrug
# 2478               HCC38      WAE     2.0          0.0           0.0  noDrug
# 5550               HCC38      WAE     3.0          0.0           0.0  noDrug
# 2457               HCC38      WAE     2.0          0.0           0.0  noDrug
# 106                HCC38      WAE     1.0          0.0           0.0  noDrug
#
#            pertLabel  IC50  NY
# Sample_ID
# B3658             no   NaN   N
# B1448             no   NaN   N
# B3663             no   NaN   N
# B3848             no   NaN   N
# B1450             no   NaN   N
# ...              ...   ...  ..
# 1618              no   NaN   N
# 2478              no   NaN   N
# 5550              no   NaN   N
# 2457              no   NaN   N
# 106               no   NaN   N
#
# [1111 rows x 5592 columns]

# %%
# ----------------------------------------------------------------------
# 14. Save final data
# ----------------------------------------------------------------------
data_final.to_csv('data/preprocessed.csv')

print("Data preprocessing complete. Example final shape:", data_final.shape)
# Out:
# Data preprocessing complete. Example final shape: (15002, 5592)

# %%
data_final[(data_final["type"] == "drugCombination") & (data_final["pertLabel"] == "#64 #56")][["Anchor_dose", "Library_dose"]].value_counts()
# Out:
# Anchor_dose  Library_dose
# 0.10         4.0             61
# 4.00         10.0            53
# 0.01         4.0             43
# 1.00         10.0            43
# Name: count, dtype: int64
